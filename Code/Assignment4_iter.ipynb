# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd 
import numpy as np


class OPTIMISER:
    
    def __init__(self):
        pass
    
    def example(self, a, objective):
        try:
            m = gp.Model("mip1")

            # Import data 
            path = "C:\\Users\\Arbeitsaccount\\Downloads\\SeminarCase1\\data_compos.xlsx"
            df2 = pd.read_excel(path)
            path = "C:\\Users\\Arbeitsaccount\\Downloads\\SeminarCase1\\Railway services-2024.xlsx"
            df3 = pd.read_excel(path)
            #df3 = df3.iloc[:-3]
            f = df2["Costs"]
            set = ["OH", "OC"]
            # Define the dimensions of the 3D matrix
            dim1 = 250
            dim2 = 200
            dim3 = 10

            # Create an empty 3D matrix (filled with uninitialized values)
            l = np.empty((dim1, dim2, dim3))
            s = np.empty((dim1, dim2, dim3))
            demand = np.empty((dim1, dim2))


            # Add values to specific elements of the matrix
            # matrix[0, 1, 2] = 10
            # matrix[1, 2, 3] = 20

            for t in range(250):
                for c in range(200):
                    # np.random.seed(30)
                    demand[t,c] = np.random.normal(df3["Demand(μ)"][c], df3["Demand(σ)"][c])
                    for p in range(10):
                        if demand[t,c] < df2["Capacity"][p]:
                            l[t,c,p] = 1
                            s[t,c,p] = 1
                        elif demand[t,c] == df2["Capacity"][p]:
                            l[t,c,p] = 0
                            s[t,c,p] = 1
                        else:
                            l[t,c,p] = 0
                            s[t,c,p] = 0
 

            x = {}
            for c in range(200):  # Define the first index range
                for p in range(10) :  # Define the second index range
                    x[c, p] = m.addVar(vtype=GRB.BINARY, name=f"x[{c},{p}]") 
            
            m.setObjective(gp.quicksum(x[c, p] * f[p] for c in range(200) for p in range(10)), GRB.MINIMIZE)
            
            for c in range(200):
                m.addConstr(gp.quicksum(x[c, p] for p in range(10)) == 1)
                if df3["Line"][c] == 400:
                    m.addConstr(gp.quicksum(x[c, p] * df2["Length"][p] for p in range(10)) <= 200)

            
            for u in set:
                for k in set:
                    if u != k:
                       m.addConstr(gp.quicksum(x[c,p] * df2[u][p] - x[c,p] * df2[k][p]  for c in range(200) for p in range(10)) <= gp.quicksum(x[c,p] * df2[k][p]  for c in range(200) for p in range(10)) * 0.25)

            

            m.addConstr(gp.quicksum(x[c,p] * l[t,c,p] for c in range(200) for t in range(250) for p in range(10)) >= 0.81 * 50000)

            for c in range(200):
                m.addConstr(gp.quicksum(x[c,p] * s[t,c,p] for t in range(250) for p in range(10)) >= 125)

                                #CONSTRAINT FOR LENGTH IS MISSING!!!!!!!!!!!!!!!!!!!!!!!!!!!

            m.optimize()
            
            #for v in m.getVars():
            #    print("%s %g" % (v.varName, v.x))
            
            objective[a] = m.objVal
            print("Obj: %g" % m.objVal)
            
        except gp.GurobiError as e:
            print("Error code " + str(e.errno) + ": " + str(e))
        except AttributeError:
            print("Encountered an attribute error")
    
    def iterations(self, a):        
        objective = np.empty(a)
        for i in range(a):
            optimizer.example(i, objective)
        print("mean: " + np.mean(objective))
        print("stdev: " + np.std(objective))
        print(objective)

if __name__ == "__main__":
    optimizer = OPTIMISER()
    numOfIterations = 100
    optimizer.iterations(numOfIterations)
# Out:
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-7200U CPU @ 2.50GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 427 rows, 2000 columns and 10060 nonzeros
# Model fingerprint: 0x50936923
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 3e+02]
#   Objective range  [2e+05, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+04]
# Found heuristic solution: objective 1.232900e+08
# Presolve removed 227 rows and 541 columns
# Presolve time: 0.03s
# Presolved: 200 rows, 1459 columns, 5262 nonzeros
# Variable types: 0 continuous, 1459 integer (1459 binary)
# Found heuristic solution: objective 7.955000e+07
#
# Root relaxation: objective 7.524561e+07, 245 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.5246e+07    0    4 7.9550e+07 7.5246e+07  5.41%     -    0s
# H    0     0                    7.579000e+07 7.5246e+07  0.72%     -    0s
# H    0     0                    7.532000e+07 7.5246e+07  0.10%     -    0s
#      0     0 7.5289e+07    0    2 7.5320e+07 7.5289e+07  0.04%     -    0s
#      0     0 7.5289e+07    0    3 7.5320e+07 7.5289e+07  0.04%     -    0s
#      0     0 7.5289e+07    0    2 7.5320e+07 7.5289e+07  0.04%     -    0s
#      0     0     cutoff    0      7.5320e+07 7.5320e+07  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   RLT: 1
#
# Explored 1 nodes (271 simplex iterations) in 0.28 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 6: 7.532e+07 7.532e+07 7.532e+07 ... 1.2329e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.532000000000e+07, best bound 7.532000000000e+07, gap 0.0000%
# Obj: 7.532e+07
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i5-7200U CPU @ 2.50GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 427 rows, 2000 columns and 10066 nonzeros
# Model fingerprint: 0x8e276b5d
# Variable types: 0 continuous, 2000 integer (2000 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 3e+02]
#   Objective range  [2e+05, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+04]
# Found heuristic solution: objective 1.229600e+08
# Presolve removed 227 rows and 544 columns
# Presolve time: 0.04s
# Presolved: 200 rows, 1456 columns, 5259 nonzeros
# Variable types: 0 continuous, 1456 integer (1456 binary)
# Found heuristic solution: objective 7.960000e+07
#
# Root relaxation: objective 7.547379e+07, 240 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.5474e+07    0    4 7.9600e+07 7.5474e+07  5.18%     -    0s
# H    0     0                    7.574000e+07 7.5474e+07  0.35%     -    0s
# H    0     0                    7.553000e+07 7.5474e+07  0.07%     -    0s
#      0     0 7.5509e+07    0    1 7.5530e+07 7.5509e+07  0.03%     -    0s
#      0     0 7.5509e+07    0    2 7.5530e+07 7.5509e+07  0.03%     -    0s
#      0     0     cutoff    0      7.5530e+07 7.5530e+07  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#
# Explored 1 nodes (251 simplex iterations) in 0.18 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 6: 7.553e+07 7.553e+07 7.553e+07 ... 1.2296e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.553000000000e+07, best bound 7.553000000000e+07, gap 0.0000%
# Obj: 7.553e+07
# 75425000.0
# 105000.0
# [75320000. 75530000.]
